# %%
#!/usr/bin/env python
# -*- encoding: utf-8 -*-
'''
@文件        :Untitled-1.ipynb
@说明        :
@时间        :2023/02/20 14:27:40
@作者        :Wu Baosheng
@版本        :1.0
'''

# %%
import pandas as pd
import numpy as np
import re,sys,os
os.chdir('H:/002.singcell/01.liver/10.mutileSpecies/05.SAMap')

# %%
x=pd.read_csv('hydra.tsv',sep='\t',header=0,index_col=0)

# %%
x['eggNOG_OGs']

# %%
df = pd.read_csv('H:/002.singcell/01.liver/10.mutileSpecies/05.SAMap/02.eggNOG/MM_k5p15yf6.emapper.annotations_lamprey.tsv',sep='\t',comment='#',header=None,index_col=0)

# %%
df.index.name=None

# %%
egg = []
for i in df[4]:
    tmp = i.split(',')
    x = ''
    for i in tmp:
        j = re.sub(r'\|.*','',i)
        x = j+"," + x
    egg.append(x)

# %%
df['eggNOG_OGs'] = egg

# %%
df.rename(columns={6:'KOG'},inplace=True)

# %%
df.to_csv('H:/002.singcell/01.liver/10.mutileSpecies/05.SAMap/02.eggNOG/lamprey.annotations.tsv',sep='\t')

# %%
df.shape
# Out:
# (11778, 21)

# %%
df = pd.read_csv('H:/002.singcell/01.liver/10.mutileSpecies/05.SAMap/02.eggNOG/human.annotations.tsv',sep='\t',header=0,index_col=0)

# %%
df = df[~df.index.duplicated(keep='first')]

# %%
df.sort_index(inplace=True)

# %%
df.index.is_unique
# Out:
# True

# %%
[print(x) for x in df.index if df.index.to_list().count(x)>1]
# Out:
# []

# %%
df
# Out:
#                                 1              2       3  \
# A1BG         9606.ENSP00000263100   0.000000e+00  1003.0
# A1CF          9597.XP_003806379.1   0.000000e+00  1157.0
# A2M          9606.ENSP00000323929   0.000000e+00  2842.0
# A2ML1        9606.ENSP00000299698   0.000000e+00  2925.0
# A3GALT2      9606.ENSP00000475261  1.560000e-258   707.0
# ...                           ...            ...     ...
# ZYG11A       9606.ENSP00000360583  1.700000e-296   823.0
# ZYG11B   60711.ENSCSAP00000016734   0.000000e+00  1479.0
# ZYX          9606.ENSP00000324422   0.000000e+00   901.0
# ZZEF1        9606.ENSP00000371051   0.000000e+00  5791.0
# ZZZ3     43179.ENSSTOP00000014732  1.350000e-303   827.0
#
#                                                          4              5 KOG  \
# A1BG     2A7TG@1|root,2RYEX@2759|Eukaryota,3914K@33154|...  33208|Metazoa   O
# A1CF     KOG0117@1|root,KOG0117@2759|Eukaryota,38B4M@33...  33208|Metazoa   A
# ...
